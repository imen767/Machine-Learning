# %%
# Import des bibliothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Affichage amélioré
pd.set_option('display.max_columns', None)
sns.set_theme(style="whitegrid")

print("✅ Bibliothèques importées avec succès !")
# Out:
# ✅ Bibliothèques importées avec succès !

# %%
# Chargement du dataset
df = pd.read_csv('../data/raw/retail_customers_COMPLETE_CATEGORICAL.csv')

print(f"✅ Dataset chargé !")
print(f"👉 Nombre de clients : {df.shape[0]}")
print(f"👉 Nombre de features : {df.shape[1]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Chargement du dataset
# ----> 2 df = pd.read_csv('../data/raw/retail_customers_COMPLETE_CATEGORICAL.csv')
#       4 print(f"✅ Dataset chargé !")
#       5 print(f"👉 Nombre de clients : {df.shape[0]}")
#
# ...

# %%
import os
print("Je suis ici :", os.getcwd())
print("\nFichiers dans le dossier data/raw :")
print(os.listdir('../data/raw'))
# Out:
# Je suis ici : C:\Users\rabdelmoula\Documents\Machine-Learning\projet_ml_retail\notebooks
#
# Fichiers dans le dossier data/raw :
# ['retail_customers_COMPLETE_CATEGORICAL - retail_customers_COMPLETE_CATEGORICAL.csv']

# %%
# Chemin absolu (plus fiable)
df = pd.read_csv(r'C:\Users\rabdelmoula\Documents\Machine-Learning\projet_ml_retail\data\raw\retail_customers_COMPLETE_CATEGORICAL.csv')

print(f"✅ Dataset chargé !")
print(f"👉 Nombre de clients : {df.shape[0]}")
print(f"👉 Nombre de features : {df.shape[1]}")
# Out:
# ✅ Dataset chargé !
# 👉 Nombre de clients : 4372
# 👉 Nombre de features : 52

# %%
# Afficher les 5 premières lignes
df.head()
# Out:
#    CustomerID  Recency  Frequency  MonetaryTotal  MonetaryAvg  MonetaryStd  \
# 0       17850      302         35        5288.63    16.950737    13.603662
# 1       13047       32         18        3079.10    15.709694    11.684769
# 2       12583        3         18        7187.34    28.634821    23.150132
# 3       13748       96          5         948.25    33.866071    42.953119
# 4       15100      330          6         635.10   105.850000   215.986263
#
#    MonetaryMin  MonetaryMax  TotalQuantity  AvgQuantityPerTransaction  \
# 0       -30.60       107.25           1693                   5.426282
# 1       -15.00        68.00           1355                   6.913265
# 2       -60.84       132.80           5009                  19.956175
# 3         9.36       204.00            439                  15.678571
# 4      -131.40       350.40             58                   9.666667
#
#    MinQuantity  MaxQuantity  CustomerTenureDays  FirstPurchaseDaysAgo  \
# ...

# %%
# Structure générale
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4372 entries, 0 to 4371
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 4372 non-null   int64
#  1   Recency                    4372 non-null   int64
#  2   Frequency                  4372 non-null   int64
#  3   MonetaryTotal              4372 non-null   float64
#  4   MonetaryAvg                4372 non-null   float64
#  5   MonetaryStd                4372 non-null   float64
#  6   MonetaryMin                4372 non-null   float64
#  7   MonetaryMax                4372 non-null   float64
#  8   TotalQuantity              4372 non-null   int64
#  9   AvgQuantityPerTransaction  4372 non-null   float64
#  10  MinQuantity                4372 non-null   int64
#  11  MaxQuantity                4372 non-null   int64
#  12  CustomerTenureDays         4372 non-null   int64
# ...

# %%
# Statistiques (moyenne, min, max, écart-type...)
df.describe()
# Out:
#          CustomerID      Recency    Frequency  MonetaryTotal  MonetaryAvg  \
# count   4372.000000  4372.000000  4372.000000    4372.000000  4372.000000
# mean   15299.677722    92.047118     5.075480    1898.459701    28.839013
# std     1722.390705   100.765435     9.338754    8219.345141   127.323926
# min    12346.000000     1.000000     1.000000   -4287.630000 -4287.630000
# 25%    13812.750000    17.000000     1.000000     293.362500    10.985960
# 50%    15300.500000    50.000000     3.000000     648.075000    16.918616
# 75%    16778.250000   143.000000     5.000000    1611.725000    23.542941
# max    18287.000000   374.000000   248.000000  279489.020000  3861.000000
#
#          MonetaryStd    MonetaryMin    MonetaryMax  TotalQuantity  \
# count    4372.000000    4372.000000    4372.000000    4372.000000
# mean       88.672383     -86.425754     185.179522    1122.344007
# std      2689.001161    2876.398935    2881.283699    4672.790720
# ...

# %%
# Valeurs manquantes par colonne
missing = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    'Valeurs manquantes': missing,
    'Pourcentage (%)': missing_percent.round(2)
})

# Afficher seulement les colonnes qui ont des valeurs manquantes
print(missing_df[missing_df['Valeurs manquantes'] > 0])
# Out:
#                          Valeurs manquantes  Pourcentage (%)
# AvgDaysBetweenPurchases                  79             1.81
# Age                                    1311            29.99

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
df['Recency'].hist(bins=30, color='steelblue', edgecolor='white')
plt.title('Distribution Recency')
plt.xlabel('Jours depuis dernier achat')
plt.ylabel('Nombre de clients')

plt.subplot(1, 2, 2)
df['Frequency'].hist(bins=30, color='coral', edgecolor='white')
plt.title('Distribution Frequency')
plt.xlabel('Nombre de commandes')
plt.ylabel('Nombre de clients')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))

# Comptage
churn_counts = df['Churn'].value_counts()
colors = ['steelblue', 'coral']

plt.subplot(1, 2, 1)
churn_counts.plot(kind='bar', color=colors, edgecolor='white')
plt.title('Répartition du Churn')
plt.xlabel('0 = Fidèle  |  1 = Parti')
plt.ylabel('Nombre de clients')
plt.xticks(rotation=0)

plt.subplot(1, 2, 2)
plt.pie(churn_counts, labels=['Fidèle', 'Parti'], colors=colors,
        autopct='%1.1f%%', startangle=90)
plt.title('% Churn')

plt.tight_layout()
plt.show()

print(f"Clients fidèles : {churn_counts[0]} ({churn_counts[0]/len(df)*100:.1f}%)")
print(f"Clients partis  : {churn_counts[1]} ({churn_counts[1]/len(df)*100:.1f}%)")
# Out:
# Clients fidèles : 2918 (66.7%)
# Clients partis  : 1454 (33.3%)
